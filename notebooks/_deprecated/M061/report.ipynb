# %% [markdown]
# # M061 Reports

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append("../../")

import pyaldata as pyal
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

from tools.reports.report_initial import run_initial_report
from tools.params import Params, colors
from tools.dsp.preprocessing import preprocess
import tools.viz.mean_firing as firing
import tools.viz.dimensionality as dim
import tools.viz.utilityTools as vizutils
import tools.decoding.rrr as rrr
import tools.decoding.decodeTools as decutils
import tools.dataTools as dt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 4th March 10:00h

# %%
# Files 
data_dir = "/data/bnd-data/raw/M061/M061_2025_03_04_10_00"
fname0 = os.path.join(data_dir, "M061_2025_03_04_10_00_pyaldata_0.mat")
fname1 = os.path.join(data_dir, "M061_2025_03_04_10_00_pyaldata_1.mat")
fname2 = os.path.join(data_dir, "M061_2025_03_04_10_00_pyaldata_2.mat")


# Load files
df0 = pyal.mat2dataframe(fname0, shift_idx_fields=False)
df1 = pyal.mat2dataframe(fname1, shift_idx_fields=False)
df2 = pyal.mat2dataframe(fname2, shift_idx_fields=False)

df = pd.concat([df0, df1, df2], ignore_index=True)

del df0
del df1
del df2

df_ = preprocess(df, only_trials=False, repair_time_varying_fields=['MotSen1_X', 'MotSen1_Y'])

# %%
from scipy import stats
from tools import params
from tools.dsp.utils import moving_window_mean
from tools.viz.utilityTools import shaded_errorbar

window = 5  # in seconds
session = 'M061_2025_03_04_10_00'

fig, ax = plt.subplots(2, 1, figsize=(20, 5), sharex='all', gridspec_kw={'height_ratios': [3, 1]})
areas=["MOp", "SSp", "CP", "VAL"]


for area in areas:
    all_rates = np.concatenate(df_[f"{area}_rates"].values, axis=0)
    means, time_bins = moving_window_mean(all_rates, int(window / Params.BIN_SIZE))
    shaded_errorbar(ax[0], x=time_bins * Params.BIN_SIZE, y=means, errorStat=stats.sem, 
                    color=getattr(params.colors, f"{area}_light", "k"),
                    label=area
                    )
    
all_motion_sensor_x = np.concatenate(df_[f"values_MotSen1_X"].values, axis=0)
all_motion_sensor_y = np.concatenate(df_[f"values_MotSen1_Y"].values, axis=0)

motion_sensor_means_x, _ = moving_window_mean(all_motion_sensor_x, int(window / Params.BIN_SIZE))
motion_sensor_means_y, _ = moving_window_mean(all_motion_sensor_y, int(window / Params.BIN_SIZE))

ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_x, label='x')
ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_y, label='y')
ax[1].set_ylabel(f'Motion Sensors')
ax[1].legend()


ax[0].set_ylabel(f'Means rate in {window} seconds')
ax[1].set_xlabel(f' Time (s)')
ax[0].axvline(x=480, color="k", linestyle="--")
ax[0].axvline(x=3660, color="k", linestyle="--")
ax[0].set_title(f'Firing rates over time. Session: {session}')
ax[0].legend()

# %%
run_initial_report(df, areas=["MOp", "SSp", "CP", "VAL", "GPe"])
# Out:
# field values_before_camera_trigger could not be converted to int.
# field idx_before_camera_trigger could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# field idx_motion could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# field values_Sol_direction could not be converted to int.
# field idx_Sol_direction could not be converted to int.
# field values_Sol_duration could not be converted to int.
# field idx_Sol_duration could not be converted to int.
# field idx_sol_on could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: values_MotSen1_X might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: idx_MotSen1_X might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: values_MotSen1_Y might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: idx_MotSen1_Y might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: values_MotSen1_X might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: idx_MotSen1_X might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: values_MotSen1_Y might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: idx_MotSen1_Y might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# Combined every 3 bins
# Resulting VAL_spikes ephys data shape is (NxT): (240, 20000)
# Resulting SSp_spikes ephys data shape is (NxT): (59, 20000)
# Resulting all_spikes ephys data shape is (NxT): (53, 20000)
# Resulting CP_spikes ephys data shape is (NxT): (225, 20000)
# Resulting MOp_spikes ephys data shape is (NxT): (206, 20000)
# Resulting GPe_spikes ephys data shape is (NxT): (112, 20000)

# %%
from tools.dsp.preprocessing import preprocess


df_ = preprocess(df)
# Out:
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: values_MotSen1_X might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: idx_MotSen1_X might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: values_MotSen1_Y might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/utils.py:155: UserWarning: idx_MotSen1_Y might be a time-varying field. It matches the length of VAL_spikes on 99.8529411764706% of trials
#   warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# Combined every 3 bins
# Resulting VAL_spikes ephys data shape is (NxT): (240, 200)
# Resulting SSp_spikes ephys data shape is (NxT): (59, 200)
# Resulting all_spikes ephys data shape is (NxT): (53, 200)
# Resulting CP_spikes ephys data shape is (NxT): (225, 200)
# Resulting MOp_spikes ephys data shape is (NxT): (206, 200)
# Resulting GPe_spikes ephys data shape is (NxT): (112, 200)

# %%
from tools.viz.dimensionality import plot_latents
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

with plt.style.context('seaborn-v0_8-bright'):
    sns.set_theme(context='talk', style='ticks')
    fig, ax = plot_latents(
        df_, 
        areas=["MOp", "SSp", "CP", "VAL"], 
        n_components=3, 
        errorbars=True, 
        errorStat=np.std, 
        show=False,
        figsize=(15, 9)
    )
    ax[-1, -1].set_xlim([50, 120])


figpath = Path('/home/me24/tmp_results')

fig.savefig(figpath / 'latents_1.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5th March 14:00h

# %%
# Files 
data_dir = "/data/bnd-data/raw/M061/M061_2025_03_05_14_00"
fname0 = os.path.join(data_dir, "M061_2025_03_05_14_00_pyaldata_0.mat")
fname1 = os.path.join(data_dir, "M061_2025_03_05_14_00_pyaldata_1.mat")


# Load files
df0 = pyal.mat2dataframe(fname0, shift_idx_fields=True)
df1 = pyal.mat2dataframe(fname1, shift_idx_fields=True)
df = pd.concat([df0, df1], ignore_index=True)

# run_initial_report(df, areas=["MOp", "SSp_ul", "CP", "Thal"])
df_ = preprocess(df, only_trials=False, repair_time_varying_fields=['MotSen1_X', 'MotSen1_Y'])
# Out:
# field values_before_camera_trigger could not be converted to int.
# field idx_before_camera_trigger could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# field idx_motion could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# Repairing columns ['MotSen1_X', 'MotSen1_Y']
# Extending index to 59999 in trial: free and id: 0, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 1, inserting NaN.
# Extending index to 599 in trial: trial and id: 2, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 3, inserting NaN.
# Extending index to 599 in trial: trial and id: 4, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 5, inserting NaN.
# Extending index to 599 in trial: trial and id: 6, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 7, inserting NaN.
# Extending index to 599 in trial: trial and id: 8, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 9, inserting NaN.
# Extending index to 599 in trial: trial and id: 10, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 11, inserting NaN.
# Extending index to 599 in trial: trial and id: 12, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 13, inserting NaN.
# Extending index to 599 in trial: trial and id: 14, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 15, inserting NaN.
# Extending index to 599 in trial: trial and id: 16, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 17, inserting NaN.
# Extending index to 599 in trial: trial and id: 18, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 19, inserting NaN.
# Extending index to 599 in trial: trial and id: 20, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 21, inserting NaN.
# Extending index to 599 in trial: trial and id: 22, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 23, inserting NaN.
# Extending index to 599 in trial: trial and id: 24, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 25, inserting NaN.
# Extending index to 599 in trial: trial and id: 26, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 27, inserting NaN.
# Extending index to 599 in trial: trial and id: 28, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 29, inserting NaN.
# Extending index to 599 in trial: trial and id: 30, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 31, inserting NaN.
# Extending index to 599 in trial: trial and id: 32, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 33, inserting NaN.
# Extending index to 599 in trial: trial and id: 34, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 35, inserting NaN.
# Extending index to 599 in trial: trial and id: 36, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 37, inserting NaN.
# Extending index to 599 in trial: trial and id: 38, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 39, inserting NaN.
# Extending index to 599 in trial: trial and id: 40, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 41, inserting NaN.
# Extending index to 599 in trial: trial and id: 42, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 43, inserting NaN.
# Extending index to 599 in trial: trial and id: 44, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 45, inserting NaN.
# Extending index to 599 in trial: trial and id: 46, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 47, inserting NaN.
# Extending index to 599 in trial: trial and id: 48, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 49, inserting NaN.
# Extending index to 599 in trial: trial and id: 50, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 51, inserting NaN.
# Extending index to 599 in trial: trial and id: 52, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 53, inserting NaN.
# Extending index to 599 in trial: trial and id: 54, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 55, inserting NaN.
# Extending index to 599 in trial: trial and id: 56, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 57, inserting NaN.
# Extending index to 599 in trial: trial and id: 58, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 59, inserting NaN.
# Extending index to 599 in trial: trial and id: 60, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 61, inserting NaN.
# Extending index to 599 in trial: trial and id: 62, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 63, inserting NaN.
# Extending index to 599 in trial: trial and id: 64, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 65, inserting NaN.
# Extending index to 599 in trial: trial and id: 66, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 67, inserting NaN.
# Extending index to 599 in trial: trial and id: 68, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 69, inserting NaN.
# Extending index to 599 in trial: trial and id: 70, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 71, inserting NaN.
# Extending index to 599 in trial: trial and id: 72, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 73, inserting NaN.
# Extending index to 599 in trial: trial and id: 74, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 75, inserting NaN.
# Extending index to 599 in trial: trial and id: 76, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 77, inserting NaN.
# Extending index to 599 in trial: trial and id: 78, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 79, inserting NaN.
# Extending index to 599 in trial: trial and id: 80, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 81, inserting NaN.
# Extending index to 599 in trial: trial and id: 82, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 83, inserting NaN.
# Extending index to 599 in trial: trial and id: 84, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 85, inserting NaN.
# Extending index to 599 in trial: trial and id: 86, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 87, inserting NaN.
# Extending index to 599 in trial: trial and id: 88, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 89, inserting NaN.
# Extending index to 599 in trial: trial and id: 90, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 91, inserting NaN.
# Extending index to 599 in trial: trial and id: 92, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 93, inserting NaN.
# Extending index to 599 in trial: trial and id: 94, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 95, inserting NaN.
# Extending index to 599 in trial: trial and id: 96, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 97, inserting NaN.
# Extending index to 599 in trial: trial and id: 98, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 99, inserting NaN.
# Extending index to 599 in trial: trial and id: 100, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 101, inserting NaN.
# Extending index to 599 in trial: trial and id: 102, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 103, inserting NaN.
# Extending index to 599 in trial: trial and id: 104, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 105, inserting NaN.
# Extending index to 599 in trial: trial and id: 106, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 107, inserting NaN.
# Extending index to 599 in trial: trial and id: 108, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 109, inserting NaN.
# Extending index to 599 in trial: trial and id: 110, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 111, inserting NaN.
# Extending index to 599 in trial: trial and id: 112, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 113, inserting NaN.
# Extending index to 599 in trial: trial and id: 114, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 115, inserting NaN.
# Extending index to 599 in trial: trial and id: 116, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 117, inserting NaN.
# Extending index to 599 in trial: trial and id: 118, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 119, inserting NaN.
# Extending index to 599 in trial: trial and id: 120, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 121, inserting NaN.
# Extending index to 599 in trial: trial and id: 122, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 123, inserting NaN.
# Extending index to 599 in trial: trial and id: 124, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 125, inserting NaN.
# Extending index to 599 in trial: trial and id: 126, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 127, inserting NaN.
# Extending index to 599 in trial: trial and id: 128, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 129, inserting NaN.
# Extending index to 599 in trial: trial and id: 130, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 131, inserting NaN.
# Extending index to 599 in trial: trial and id: 132, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 133, inserting NaN.
# Extending index to 599 in trial: trial and id: 134, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 135, inserting NaN.
# Extending index to 599 in trial: trial and id: 136, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 137, inserting NaN.
# Extending index to 599 in trial: trial and id: 138, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 139, inserting NaN.
# Extending index to 599 in trial: trial and id: 140, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 141, inserting NaN.
# Extending index to 599 in trial: trial and id: 142, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 143, inserting NaN.
# Extending index to 599 in trial: trial and id: 144, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 145, inserting NaN.
# Extending index to 599 in trial: trial and id: 146, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 147, inserting NaN.
# Extending index to 599 in trial: trial and id: 148, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 149, inserting NaN.
# Extending index to 599 in trial: trial and id: 150, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 151, inserting NaN.
# Extending index to 599 in trial: trial and id: 152, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 153, inserting NaN.
# Extending index to 599 in trial: trial and id: 154, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 155, inserting NaN.
# Extending index to 599 in trial: trial and id: 156, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 157, inserting NaN.
# Extending index to 599 in trial: trial and id: 158, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 159, inserting NaN.
# Extending index to 599 in trial: trial and id: 160, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 161, inserting NaN.
# Extending index to 599 in trial: trial and id: 162, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 163, inserting NaN.
# Extending index to 599 in trial: trial and id: 164, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 165, inserting NaN.
# Extending index to 599 in trial: trial and id: 166, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 167, inserting NaN.
# Extending index to 599 in trial: trial and id: 168, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 169, inserting NaN.
# Extending index to 599 in trial: trial and id: 170, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 171, inserting NaN.
# Extending index to 599 in trial: trial and id: 172, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 173, inserting NaN.
# Extending index to 599 in trial: trial and id: 174, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 175, inserting NaN.
# Extending index to 599 in trial: trial and id: 176, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 177, inserting NaN.
# Extending index to 599 in trial: trial and id: 178, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 179, inserting NaN.
# Extending index to 599 in trial: trial and id: 180, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 181, inserting NaN.
# Extending index to 599 in trial: trial and id: 182, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 183, inserting NaN.
# Extending index to 599 in trial: trial and id: 184, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 185, inserting NaN.
# Extending index to 599 in trial: trial and id: 186, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 187, inserting NaN.
# Extending index to 599 in trial: trial and id: 188, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 189, inserting NaN.
# Extending index to 599 in trial: trial and id: 190, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 191, inserting NaN.
# Extending index to 599 in trial: trial and id: 192, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 193, inserting NaN.
# Extending index to 599 in trial: trial and id: 194, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 195, inserting NaN.
# Extending index to 599 in trial: trial and id: 196, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 197, inserting NaN.
# Extending index to 599 in trial: trial and id: 198, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 199, inserting NaN.
# Extending index to 599 in trial: trial and id: 200, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 201, inserting NaN.
# Extending index to 599 in trial: trial and id: 202, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 203, inserting NaN.
# Extending index to 599 in trial: trial and id: 204, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 205, inserting NaN.
# Extending index to 599 in trial: trial and id: 206, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 207, inserting NaN.
# Extending index to 599 in trial: trial and id: 208, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 209, inserting NaN.
# Extending index to 599 in trial: trial and id: 210, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 211, inserting NaN.
# Extending index to 599 in trial: trial and id: 212, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 213, inserting NaN.
# Extending index to 599 in trial: trial and id: 214, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 215, inserting NaN.
# Extending index to 599 in trial: trial and id: 216, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 217, inserting NaN.
# Extending index to 599 in trial: trial and id: 218, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 219, inserting NaN.
# Extending index to 599 in trial: trial and id: 220, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 221, inserting NaN.
# Extending index to 599 in trial: trial and id: 222, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 223, inserting NaN.
# Extending index to 599 in trial: trial and id: 224, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 225, inserting NaN.
# Extending index to 599 in trial: trial and id: 226, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 227, inserting NaN.
# Extending index to 599 in trial: trial and id: 228, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 229, inserting NaN.
# Extending index to 599 in trial: trial and id: 230, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 231, inserting NaN.
# Extending index to 599 in trial: trial and id: 232, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 233, inserting NaN.
# Extending index to 599 in trial: trial and id: 234, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 235, inserting NaN.
# Extending index to 599 in trial: trial and id: 236, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 237, inserting NaN.
# Extending index to 599 in trial: trial and id: 238, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 239, inserting NaN.
# Extending index to 599 in trial: trial and id: 240, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 241, inserting NaN.
# Extending index to 599 in trial: trial and id: 242, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 243, inserting NaN.
# Extending index to 599 in trial: trial and id: 244, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 245, inserting NaN.
# Extending index to 599 in trial: trial and id: 246, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 247, inserting NaN.
# Extending index to 599 in trial: trial and id: 248, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 249, inserting NaN.
# Extending index to 599 in trial: trial and id: 250, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 251, inserting NaN.
# Extending index to 599 in trial: trial and id: 252, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 253, inserting NaN.
# Extending index to 599 in trial: trial and id: 254, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 255, inserting NaN.
# Extending index to 599 in trial: trial and id: 256, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 257, inserting NaN.
# Extending index to 599 in trial: trial and id: 258, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 259, inserting NaN.
# Extending index to 599 in trial: trial and id: 260, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 261, inserting NaN.
# Extending index to 599 in trial: trial and id: 262, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 263, inserting NaN.
# Extending index to 599 in trial: trial and id: 264, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 265, inserting NaN.
# Extending index to 599 in trial: trial and id: 266, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 267, inserting NaN.
# Extending index to 599 in trial: trial and id: 268, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 269, inserting NaN.
# Extending index to 599 in trial: trial and id: 270, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 271, inserting NaN.
# Extending index to 599 in trial: trial and id: 272, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 273, inserting NaN.
# Extending index to 599 in trial: trial and id: 274, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 275, inserting NaN.
# Extending index to 599 in trial: trial and id: 276, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 277, inserting NaN.
# Extending index to 599 in trial: trial and id: 278, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 279, inserting NaN.
# Extending index to 599 in trial: trial and id: 280, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 281, inserting NaN.
# Extending index to 599 in trial: trial and id: 282, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 283, inserting NaN.
# Extending index to 599 in trial: trial and id: 284, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 285, inserting NaN.
# Extending index to 599 in trial: trial and id: 286, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 287, inserting NaN.
# Extending index to 599 in trial: trial and id: 288, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 289, inserting NaN.
# Extending index to 599 in trial: trial and id: 290, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 291, inserting NaN.
# Extending index to 599 in trial: trial and id: 292, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 293, inserting NaN.
# Extending index to 599 in trial: trial and id: 294, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 295, inserting NaN.
# Extending index to 599 in trial: trial and id: 296, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 297, inserting NaN.
# Extending index to 599 in trial: trial and id: 298, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 299, inserting NaN.
# Extending index to 599 in trial: trial and id: 300, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 301, inserting NaN.
# Extending index to 599 in trial: trial and id: 302, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 303, inserting NaN.
# Extending index to 599 in trial: trial and id: 304, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 305, inserting NaN.
# Extending index to 599 in trial: trial and id: 306, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 307, inserting NaN.
# Extending index to 599 in trial: trial and id: 308, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 309, inserting NaN.
# Extending index to 599 in trial: trial and id: 310, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 311, inserting NaN.
# Extending index to 600 in trial: trial and id: 312, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 313, inserting NaN.
# Extending index to 599 in trial: trial and id: 314, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 315, inserting NaN.
# Extending index to 599 in trial: trial and id: 316, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 317, inserting NaN.
# Extending index to 599 in trial: trial and id: 318, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 319, inserting NaN.
# Extending index to 599 in trial: trial and id: 320, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 321, inserting NaN.
# Extending index to 599 in trial: trial and id: 322, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 323, inserting NaN.
# Extending index to 599 in trial: trial and id: 324, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 325, inserting NaN.
# Extending index to 599 in trial: trial and id: 326, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 327, inserting NaN.
# Extending index to 599 in trial: trial and id: 328, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 329, inserting NaN.
# Extending index to 599 in trial: trial and id: 330, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 331, inserting NaN.
# Extending index to 599 in trial: trial and id: 332, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 333, inserting NaN.
# Extending index to 599 in trial: trial and id: 334, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 335, inserting NaN.
# Extending index to 599 in trial: trial and id: 336, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 337, inserting NaN.
# Extending index to 599 in trial: trial and id: 338, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 339, inserting NaN.
# Extending index to 599 in trial: trial and id: 340, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 341, inserting NaN.
# Extending index to 599 in trial: trial and id: 342, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 343, inserting NaN.
# Extending index to 599 in trial: trial and id: 344, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 345, inserting NaN.
# Extending index to 599 in trial: trial and id: 346, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 347, inserting NaN.
# Extending index to 599 in trial: trial and id: 348, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 349, inserting NaN.
# Extending index to 599 in trial: trial and id: 350, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 351, inserting NaN.
# Extending index to 599 in trial: trial and id: 352, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 353, inserting NaN.
# Extending index to 599 in trial: trial and id: 354, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 355, inserting NaN.
# Extending index to 599 in trial: trial and id: 356, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 357, inserting NaN.
# Extending index to 599 in trial: trial and id: 358, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 359, inserting NaN.
# Extending index to 599 in trial: trial and id: 360, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 361, inserting NaN.
# Extending index to 599 in trial: trial and id: 362, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 363, inserting NaN.
# Extending index to 599 in trial: trial and id: 364, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 365, inserting NaN.
# Extending index to 599 in trial: trial and id: 366, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 367, inserting NaN.
# Extending index to 599 in trial: trial and id: 368, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 369, inserting NaN.
# Extending index to 599 in trial: trial and id: 370, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 371, inserting NaN.
# Extending index to 599 in trial: trial and id: 372, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 373, inserting NaN.
# Extending index to 599 in trial: trial and id: 374, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 375, inserting NaN.
# Extending index to 599 in trial: trial and id: 376, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 377, inserting NaN.
# Extending index to 599 in trial: trial and id: 378, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 379, inserting NaN.
# Extending index to 599 in trial: trial and id: 380, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 381, inserting NaN.
# Extending index to 599 in trial: trial and id: 382, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 383, inserting NaN.
# Extending index to 599 in trial: trial and id: 384, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 385, inserting NaN.
# Extending index to 599 in trial: trial and id: 386, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 387, inserting NaN.
# Extending index to 599 in trial: trial and id: 388, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 389, inserting NaN.
# Extending index to 599 in trial: trial and id: 390, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 391, inserting NaN.
# Extending index to 599 in trial: trial and id: 392, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 393, inserting NaN.
# Extending index to 599 in trial: trial and id: 394, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 395, inserting NaN.
# Extending index to 599 in trial: trial and id: 396, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 397, inserting NaN.
# Extending index to 599 in trial: trial and id: 398, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 399, inserting NaN.
# Extending index to 599 in trial: trial and id: 400, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 401, inserting NaN.
# Extending index to 599 in trial: trial and id: 402, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 403, inserting NaN.
# Extending index to 599 in trial: trial and id: 404, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 405, inserting NaN.
# Extending index to 599 in trial: trial and id: 406, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 407, inserting NaN.
# Extending index to 599 in trial: trial and id: 408, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 409, inserting NaN.
# Extending index to 599 in trial: trial and id: 410, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 411, inserting NaN.
# Extending index to 599 in trial: trial and id: 412, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 413, inserting NaN.
# Extending index to 599 in trial: trial and id: 414, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 415, inserting NaN.
# Extending index to 599 in trial: trial and id: 416, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 417, inserting NaN.
# Extending index to 599 in trial: trial and id: 418, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 419, inserting NaN.
# Extending index to 599 in trial: trial and id: 420, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 421, inserting NaN.
# Extending index to 599 in trial: trial and id: 422, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 423, inserting NaN.
# Extending index to 599 in trial: trial and id: 424, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 425, inserting NaN.
# Extending index to 599 in trial: trial and id: 426, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 427, inserting NaN.
# Extending index to 599 in trial: trial and id: 428, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 429, inserting NaN.
# Extending index to 599 in trial: trial and id: 430, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 431, inserting NaN.
# Extending index to 599 in trial: trial and id: 432, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 433, inserting NaN.
# Extending index to 599 in trial: trial and id: 434, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 435, inserting NaN.
# Extending index to 599 in trial: trial and id: 436, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 437, inserting NaN.
# Extending index to 599 in trial: trial and id: 438, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 439, inserting NaN.
# Extending index to 599 in trial: trial and id: 440, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 441, inserting NaN.
# Extending index to 599 in trial: trial and id: 442, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 443, inserting NaN.
# Extending index to 599 in trial: trial and id: 444, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 445, inserting NaN.
# Extending index to 599 in trial: trial and id: 446, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 447, inserting NaN.
# Extending index to 599 in trial: trial and id: 448, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 449, inserting NaN.
# Extending index to 599 in trial: trial and id: 450, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 451, inserting NaN.
# Extending index to 599 in trial: trial and id: 452, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 453, inserting NaN.
# Extending index to 599 in trial: trial and id: 454, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 455, inserting NaN.
# Extending index to 599 in trial: trial and id: 456, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 457, inserting NaN.
# Extending index to 599 in trial: trial and id: 458, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 459, inserting NaN.
# Extending index to 599 in trial: trial and id: 460, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 461, inserting NaN.
# Extending index to 599 in trial: trial and id: 462, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 463, inserting NaN.
# Extending index to 599 in trial: trial and id: 464, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 465, inserting NaN.
# Extending index to 599 in trial: trial and id: 466, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 467, inserting NaN.
# Extending index to 599 in trial: trial and id: 468, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 469, inserting NaN.
# Extending index to 599 in trial: trial and id: 470, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 471, inserting NaN.
# Extending index to 599 in trial: trial and id: 472, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 473, inserting NaN.
# Extending index to 599 in trial: trial and id: 474, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 475, inserting NaN.
# Extending index to 599 in trial: trial and id: 476, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 477, inserting NaN.
# Extending index to 599 in trial: trial and id: 478, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 479, inserting NaN.
# Extending index to 599 in trial: trial and id: 480, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 481, inserting NaN.
# Extending index to 599 in trial: trial and id: 482, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 483, inserting NaN.
# Extending index to 599 in trial: trial and id: 484, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 485, inserting NaN.
# Extending index to 599 in trial: trial and id: 486, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 487, inserting NaN.
# Extending index to 599 in trial: trial and id: 488, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 489, inserting NaN.
# Extending index to 599 in trial: trial and id: 490, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 491, inserting NaN.
# Extending index to 599 in trial: trial and id: 492, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 493, inserting NaN.
# Extending index to 599 in trial: trial and id: 494, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 495, inserting NaN.
# Extending index to 599 in trial: trial and id: 496, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 497, inserting NaN.
# Extending index to 599 in trial: trial and id: 498, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 499, inserting NaN.
# Extending index to 599 in trial: trial and id: 500, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 501, inserting NaN.
# Extending index to 599 in trial: trial and id: 502, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 503, inserting NaN.
# Extending index to 599 in trial: trial and id: 504, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 505, inserting NaN.
# Extending index to 599 in trial: trial and id: 506, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 507, inserting NaN.
# Extending index to 599 in trial: trial and id: 508, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 509, inserting NaN.
# Extending index to 599 in trial: trial and id: 510, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 511, inserting NaN.
# Extending index to 599 in trial: trial and id: 512, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 513, inserting NaN.
# Extending index to 599 in trial: trial and id: 514, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 515, inserting NaN.
# Extending index to 599 in trial: trial and id: 516, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 517, inserting NaN.
# Extending index to 599 in trial: trial and id: 518, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 519, inserting NaN.
# Extending index to 599 in trial: trial and id: 520, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 521, inserting NaN.
# Extending index to 599 in trial: trial and id: 522, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 523, inserting NaN.
# Extending index to 599 in trial: trial and id: 524, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 525, inserting NaN.
# Extending index to 599 in trial: trial and id: 526, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 527, inserting NaN.
# Extending index to 599 in trial: trial and id: 528, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 529, inserting NaN.
# Extending index to 599 in trial: trial and id: 530, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 531, inserting NaN.
# Extending index to 599 in trial: trial and id: 532, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 533, inserting NaN.
# Extending index to 599 in trial: trial and id: 534, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 535, inserting NaN.
# Extending index to 599 in trial: trial and id: 536, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 537, inserting NaN.
# Extending index to 599 in trial: trial and id: 538, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 539, inserting NaN.
# Extending index to 599 in trial: trial and id: 540, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 541, inserting NaN.
# Extending index to 599 in trial: trial and id: 542, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 543, inserting NaN.
# Extending index to 599 in trial: trial and id: 544, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 545, inserting NaN.
# Extending index to 599 in trial: trial and id: 546, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 547, inserting NaN.
# Extending index to 599 in trial: trial and id: 548, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 549, inserting NaN.
# Extending index to 599 in trial: trial and id: 550, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 551, inserting NaN.
# Extending index to 599 in trial: trial and id: 552, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 553, inserting NaN.
# Extending index to 599 in trial: trial and id: 554, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 555, inserting NaN.
# Extending index to 599 in trial: trial and id: 556, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 557, inserting NaN.
# Extending index to 599 in trial: trial and id: 558, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 559, inserting NaN.
# Extending index to 599 in trial: trial and id: 560, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 561, inserting NaN.
# Extending index to 599 in trial: trial and id: 562, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 563, inserting NaN.
# Extending index to 599 in trial: trial and id: 564, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 565, inserting NaN.
# Extending index to 599 in trial: trial and id: 566, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 567, inserting NaN.
# Extending index to 599 in trial: trial and id: 568, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 569, inserting NaN.
# Extending index to 599 in trial: trial and id: 570, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 571, inserting NaN.
# Extending index to 599 in trial: trial and id: 572, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 573, inserting NaN.
# Extending index to 599 in trial: trial and id: 574, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 575, inserting NaN.
# Extending index to 599 in trial: trial and id: 576, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 577, inserting NaN.
# Extending index to 599 in trial: trial and id: 578, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 579, inserting NaN.
# Extending index to 599 in trial: trial and id: 580, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 581, inserting NaN.
# Extending index to 599 in trial: trial and id: 582, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 583, inserting NaN.
# Extending index to 599 in trial: trial and id: 584, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 585, inserting NaN.
# Extending index to 599 in trial: trial and id: 586, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 587, inserting NaN.
# Extending index to 599 in trial: trial and id: 588, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 589, inserting NaN.
# Extending index to 599 in trial: trial and id: 590, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 591, inserting NaN.
# Extending index to 599 in trial: trial and id: 592, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 593, inserting NaN.
# Extending index to 599 in trial: trial and id: 594, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 595, inserting NaN.
# Extending index to 599 in trial: trial and id: 596, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 597, inserting NaN.
# Extending index to 599 in trial: trial and id: 598, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 599, inserting NaN.
# Extending index to 599 in trial: trial and id: 600, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 601, inserting NaN.
# Extending index to 599 in trial: trial and id: 602, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 603, inserting NaN.
# Extending index to 599 in trial: trial and id: 604, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 605, inserting NaN.
# Extending index to 599 in trial: trial and id: 606, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 607, inserting NaN.
# Extending index to 599 in trial: trial and id: 608, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 609, inserting NaN.
# Extending index to 599 in trial: trial and id: 610, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 611, inserting NaN.
# Extending index to 599 in trial: trial and id: 612, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 613, inserting NaN.
# Extending index to 599 in trial: trial and id: 614, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 615, inserting NaN.
# Extending index to 599 in trial: trial and id: 616, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 617, inserting NaN.
# Extending index to 599 in trial: trial and id: 618, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 619, inserting NaN.
# Extending index to 599 in trial: trial and id: 620, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 621, inserting NaN.
# Extending index to 599 in trial: trial and id: 622, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 623, inserting NaN.
# Extending index to 599 in trial: trial and id: 624, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 625, inserting NaN.
# Extending index to 599 in trial: trial and id: 626, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 627, inserting NaN.
# Extending index to 599 in trial: trial and id: 628, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 629, inserting NaN.
# Extending index to 599 in trial: trial and id: 630, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 631, inserting NaN.
# Extending index to 599 in trial: trial and id: 632, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 633, inserting NaN.
# Extending index to 599 in trial: trial and id: 634, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 635, inserting NaN.
# Extending index to 599 in trial: trial and id: 636, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 637, inserting NaN.
# Extending index to 599 in trial: trial and id: 638, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 639, inserting NaN.
# Extending index to 599 in trial: trial and id: 640, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 641, inserting NaN.
# Extending index to 599 in trial: trial and id: 642, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 643, inserting NaN.
# Extending index to 599 in trial: trial and id: 644, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 645, inserting NaN.
# Extending index to 599 in trial: trial and id: 646, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 647, inserting NaN.
# Extending index to 599 in trial: trial and id: 648, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 649, inserting NaN.
# Extending index to 599 in trial: trial and id: 650, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 651, inserting NaN.
# Extending index to 599 in trial: trial and id: 652, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 653, inserting NaN.
# Extending index to 599 in trial: trial and id: 654, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 655, inserting NaN.
# Extending index to 599 in trial: trial and id: 656, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 657, inserting NaN.
# Extending index to 599 in trial: trial and id: 658, inserting NaN.
# Extending index to 98 in trial: intertrial and id: 659, inserting NaN.
# Extending index to 53998 in trial: free and id: 660, inserting NaN.
# Extending index to 53999 in trial: free and id: 660, inserting NaN.
# Extending index to 59999 in trial: free and id: 0, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 1, inserting NaN.
# Extending index to 599 in trial: trial and id: 2, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 3, inserting NaN.
# Extending index to 599 in trial: trial and id: 4, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 5, inserting NaN.
# Extending index to 599 in trial: trial and id: 6, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 7, inserting NaN.
# Extending index to 599 in trial: trial and id: 8, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 9, inserting NaN.
# Extending index to 599 in trial: trial and id: 10, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 11, inserting NaN.
# Extending index to 599 in trial: trial and id: 12, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 13, inserting NaN.
# Extending index to 599 in trial: trial and id: 14, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 15, inserting NaN.
# Extending index to 599 in trial: trial and id: 16, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 17, inserting NaN.
# Extending index to 599 in trial: trial and id: 18, inserting NaN.
# ...
# Extending index to 599 in trial: trial and id: 466, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 467, inserting NaN.
# Extending index to 599 in trial: trial and id: 468, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 469, inserting NaN.
# Extending index to 599 in trial: trial and id: 470, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 471, inserting NaN.
# Extending index to 599 in trial: trial and id: 472, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 473, inserting NaN.
# Extending index to 599 in trial: trial and id: 474, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 475, inserting NaN.
# Extending index to 599 in trial: trial and id: 476, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 477, inserting NaN.
# Extending index to 599 in trial: trial and id: 478, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 479, inserting NaN.
# Extending index to 599 in trial: trial and id: 480, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 481, inserting NaN.
# Extending index to 599 in trial: trial and id: 482, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 483, inserting NaN.
# Extending index to 599 in trial: trial and id: 484, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 485, inserting NaN.
# Extending index to 599 in trial: trial and id: 486, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 487, inserting NaN.
# Extending index to 599 in trial: trial and id: 488, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 489, inserting NaN.
# Extending index to 599 in trial: trial and id: 490, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 491, inserting NaN.
# Extending index to 599 in trial: trial and id: 492, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 493, inserting NaN.
# Extending index to 599 in trial: trial and id: 494, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 495, inserting NaN.
# Extending index to 599 in trial: trial and id: 496, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 497, inserting NaN.
# Extending index to 599 in trial: trial and id: 498, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 499, inserting NaN.
# Extending index to 599 in trial: trial and id: 500, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 501, inserting NaN.
# Extending index to 599 in trial: trial and id: 502, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 503, inserting NaN.
# Extending index to 599 in trial: trial and id: 504, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 505, inserting NaN.
# Extending index to 599 in trial: trial and id: 506, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 507, inserting NaN.
# Extending index to 599 in trial: trial and id: 508, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 509, inserting NaN.
# Extending index to 599 in trial: trial and id: 510, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 511, inserting NaN.
# Extending index to 599 in trial: trial and id: 512, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 513, inserting NaN.
# Extending index to 599 in trial: trial and id: 514, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 515, inserting NaN.
# Extending index to 599 in trial: trial and id: 516, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 517, inserting NaN.
# Extending index to 599 in trial: trial and id: 518, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 519, inserting NaN.
# Extending index to 599 in trial: trial and id: 520, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 521, inserting NaN.
# Extending index to 599 in trial: trial and id: 522, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 523, inserting NaN.
# Extending index to 599 in trial: trial and id: 524, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 525, inserting NaN.
# Extending index to 599 in trial: trial and id: 526, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 527, inserting NaN.
# Extending index to 599 in trial: trial and id: 528, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 529, inserting NaN.
# Extending index to 599 in trial: trial and id: 530, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 531, inserting NaN.
# Extending index to 599 in trial: trial and id: 532, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 533, inserting NaN.
# Extending index to 599 in trial: trial and id: 534, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 535, inserting NaN.
# Extending index to 599 in trial: trial and id: 536, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 537, inserting NaN.
# Extending index to 599 in trial: trial and id: 538, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 539, inserting NaN.
# Extending index to 599 in trial: trial and id: 540, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 541, inserting NaN.
# Extending index to 599 in trial: trial and id: 542, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 543, inserting NaN.
# Extending index to 599 in trial: trial and id: 544, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 545, inserting NaN.
# Extending index to 599 in trial: trial and id: 546, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 547, inserting NaN.
# Extending index to 599 in trial: trial and id: 548, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 549, inserting NaN.
# Extending index to 599 in trial: trial and id: 550, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 551, inserting NaN.
# Extending index to 599 in trial: trial and id: 552, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 553, inserting NaN.
# Extending index to 599 in trial: trial and id: 554, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 555, inserting NaN.
# Extending index to 599 in trial: trial and id: 556, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 557, inserting NaN.
# Extending index to 599 in trial: trial and id: 558, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 559, inserting NaN.
# Extending index to 599 in trial: trial and id: 560, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 561, inserting NaN.
# Extending index to 599 in trial: trial and id: 562, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 563, inserting NaN.
# Extending index to 599 in trial: trial and id: 564, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 565, inserting NaN.
# Extending index to 599 in trial: trial and id: 566, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 567, inserting NaN.
# Extending index to 599 in trial: trial and id: 568, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 569, inserting NaN.
# Extending index to 599 in trial: trial and id: 570, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 571, inserting NaN.
# Extending index to 599 in trial: trial and id: 572, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 573, inserting NaN.
# Extending index to 599 in trial: trial and id: 574, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 575, inserting NaN.
# Extending index to 599 in trial: trial and id: 576, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 577, inserting NaN.
# Extending index to 599 in trial: trial and id: 578, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 579, inserting NaN.
# Extending index to 599 in trial: trial and id: 580, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 581, inserting NaN.
# Extending index to 599 in trial: trial and id: 582, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 583, inserting NaN.
# Extending index to 599 in trial: trial and id: 584, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 585, inserting NaN.
# Extending index to 599 in trial: trial and id: 586, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 587, inserting NaN.
# Extending index to 599 in trial: trial and id: 588, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 589, inserting NaN.
# Extending index to 599 in trial: trial and id: 590, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 591, inserting NaN.
# Extending index to 599 in trial: trial and id: 592, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 593, inserting NaN.
# Extending index to 599 in trial: trial and id: 594, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 595, inserting NaN.
# Extending index to 599 in trial: trial and id: 596, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 597, inserting NaN.
# Extending index to 599 in trial: trial and id: 598, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 599, inserting NaN.
# Extending index to 599 in trial: trial and id: 600, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 601, inserting NaN.
# Extending index to 599 in trial: trial and id: 602, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 603, inserting NaN.
# Extending index to 599 in trial: trial and id: 604, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 605, inserting NaN.
# Extending index to 599 in trial: trial and id: 606, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 607, inserting NaN.
# Extending index to 599 in trial: trial and id: 608, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 609, inserting NaN.
# Extending index to 599 in trial: trial and id: 610, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 611, inserting NaN.
# Extending index to 599 in trial: trial and id: 612, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 613, inserting NaN.
# Extending index to 599 in trial: trial and id: 614, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 615, inserting NaN.
# Extending index to 599 in trial: trial and id: 616, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 617, inserting NaN.
# Extending index to 599 in trial: trial and id: 618, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 619, inserting NaN.
# Extending index to 599 in trial: trial and id: 620, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 621, inserting NaN.
# Extending index to 599 in trial: trial and id: 622, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 623, inserting NaN.
# Extending index to 599 in trial: trial and id: 624, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 625, inserting NaN.
# Extending index to 599 in trial: trial and id: 626, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 627, inserting NaN.
# Extending index to 599 in trial: trial and id: 628, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 629, inserting NaN.
# Extending index to 599 in trial: trial and id: 630, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 631, inserting NaN.
# Extending index to 599 in trial: trial and id: 632, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 633, inserting NaN.
# Extending index to 599 in trial: trial and id: 634, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 635, inserting NaN.
# Extending index to 599 in trial: trial and id: 636, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 637, inserting NaN.
# Extending index to 599 in trial: trial and id: 638, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 639, inserting NaN.
# Extending index to 599 in trial: trial and id: 640, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 641, inserting NaN.
# Extending index to 599 in trial: trial and id: 642, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 643, inserting NaN.
# Extending index to 599 in trial: trial and id: 644, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 645, inserting NaN.
# Extending index to 599 in trial: trial and id: 646, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 647, inserting NaN.
# Extending index to 599 in trial: trial and id: 648, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 649, inserting NaN.
# Extending index to 599 in trial: trial and id: 650, inserting NaN.
# Extending index to 99 in trial: intertrial and id: 651, inserting NaN.
# Extending index to 599 in trial: trial and id: 652, inserting NaN.
# Extending index to 299 in trial: intertrial and id: 653, inserting NaN.
# Extending index to 599 in trial: trial and id: 654, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 655, inserting NaN.
# Extending index to 599 in trial: trial and id: 656, inserting NaN.
# Extending index to 499 in trial: intertrial and id: 657, inserting NaN.
# Extending index to 599 in trial: trial and id: 658, inserting NaN.
# Extending index to 98 in trial: intertrial and id: 659, inserting NaN.
# Extending index to 53988 in trial: free and id: 660, inserting NaN.
# Extending index to 53989 in trial: free and id: 660, inserting NaN.
# Extending index to 53990 in trial: free and id: 660, inserting NaN.
# Extending index to 53991 in trial: free and id: 660, inserting NaN.
# Extending index to 53992 in trial: free and id: 660, inserting NaN.
# Extending index to 53993 in trial: free and id: 660, inserting NaN.
# Extending index to 53994 in trial: free and id: 660, inserting NaN.
# Extending index to 53995 in trial: free and id: 660, inserting NaN.
# Extending index to 53996 in trial: free and id: 660, inserting NaN.
# Extending index to 53997 in trial: free and id: 660, inserting NaN.
# Extending index to 53998 in trial: free and id: 660, inserting NaN.
# Extending index to 53999 in trial: free and id: 660, inserting NaN.
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# Combined every 3 bins
# Resulting SSp_spikes ephys data shape is (NxT): (118, 20000)
# Resulting all_spikes ephys data shape is (NxT): (24, 20000)
# Resulting VAL_spikes ephys data shape is (NxT): (219, 20000)
# Resulting GPe_spikes ephys data shape is (NxT): (100, 20000)
# Resulting MOp_spikes ephys data shape is (NxT): (155, 20000)
# Resulting CP_spikes ephys data shape is (NxT): (195, 20000)

# %%
from scipy import stats
from tools import params
from tools.dsp.utils import moving_window_mean
from tools.viz.utilityTools import shaded_errorbar

window = 5  # in seconds
session = 'M061_2025_03_05_14_00'

fig, ax = plt.subplots(2, 1, figsize=(20, 5), sharex='all', gridspec_kw={'height_ratios': [3, 1]})
areas=["MOp", "SSp", "CP", "VAL"]


for area in areas:
    all_rates = np.concatenate(df_[f"{area}_rates"].values, axis=0)
    means, time_bins = moving_window_mean(all_rates, int(window / Params.BIN_SIZE))
    shaded_errorbar(ax[0], x=time_bins * Params.BIN_SIZE, y=means, errorStat=stats.sem, 
                    color=getattr(params.colors, f"{area}_light", "k"),
                    label=area
                    )
    
all_motion_sensor_x = np.concatenate(df_[f"values_MotSen1_X"].values, axis=0)
all_motion_sensor_y = np.concatenate(df_[f"values_MotSen1_Y"].values, axis=0)

motion_sensor_means_x, _ = moving_window_mean(all_motion_sensor_x, int(window / Params.BIN_SIZE))
motion_sensor_means_y, _ = moving_window_mean(all_motion_sensor_y, int(window / Params.BIN_SIZE))

ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_x, label='x')
ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_y, label='y')
ax[1].set_ylabel(f'Motion Sensors')
ax[1].legend()


ax[0].set_ylabel(f'Means rate in {window} seconds')
ax[1].set_xlabel(f' Time (s)')
ax[0].axvline(x=480, color="k", linestyle="--")
ax[0].axvline(x=3660, color="k", linestyle="--")
ax[0].set_title(f'Firing rates over time. Session: {session}')
ax[0].legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 27
#      24 motion_sensor_means_x, _ = moving_window_mean(all_motion_sensor_x, int(window / Params.BIN_SIZE))
#      25 motion_sensor_means_y, _ = moving_window_mean(all_motion_sensor_y, int(window / Params.BIN_SIZE))
# ---> 27 ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_x, label='x')
#      28 ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_y, label='y')
#      29 ax[1].set_ylabel(f'Motion Sensors')
#
# File ~/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/lib/python3.12/site-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (137723,) and (414496,)

# %% [markdown]
# # 6th March

# %%
# Files 
session = 'M061_2025_03_06_14_00'
data_dir = f"/data/bnd-data/raw/M061/{session}"

areas=["MOp", "SSp", "CP", "VAL"]
df = pyal.load_pyaldata(data_dir)
df_ = preprocess(df, only_trials=False, repair_time_varying_fields=['MotSen1_X', 'MotSen1_Y'])
# Out:
# field values_before_camera_trigger could not be converted to int.
# field idx_before_camera_trigger could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# array field SSp_KSLabel could not be converted to int.
# array field VAL_KSLabel could not be converted to int.
# array field all_KSLabel could not be converted to int.
# array field MOp_KSLabel could not be converted to int.
# array field CP_KSLabel could not be converted to int.
# array field GPe_KSLabel could not be converted to int.
# Repairing columns ['MotSen1_X', 'MotSen1_Y']
# Extending index to 53999 in trial: free and id: 668, inserting NaN.
# Extending index to 53989 in trial: free and id: 668, inserting NaN.
# Extending index to 53990 in trial: free and id: 668, inserting NaN.
# Extending index to 53991 in trial: free and id: 668, inserting NaN.
# Extending index to 53992 in trial: free and id: 668, inserting NaN.
# Extending index to 53993 in trial: free and id: 668, inserting NaN.
# Extending index to 53994 in trial: free and id: 668, inserting NaN.
# Extending index to 53995 in trial: free and id: 668, inserting NaN.
# Extending index to 53996 in trial: free and id: 668, inserting NaN.
# Extending index to 53997 in trial: free and id: 668, inserting NaN.
# Extending index to 53998 in trial: free and id: 668, inserting NaN.
# Extending index to 53999 in trial: free and id: 668, inserting NaN.
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# /home/me24/.cache/pypoetry/virtualenvs/earthquake-analysis-Z8riI-lB-py3.12/src/PyalData/pyaldata/firing_rates.py:108: UserWarning: Assuming spikes are actually spikes and dividing by bin size.
#   utils.warnings.warn(
# Combined every 3 bins
# Resulting SSp_spikes ephys data shape is (NxT): (69, 20000)
# Resulting VAL_spikes ephys data shape is (NxT): (168, 20000)
# Resulting all_spikes ephys data shape is (NxT): (11, 20000)
# Resulting MOp_spikes ephys data shape is (NxT): (178, 20000)
# Resulting CP_spikes ephys data shape is (NxT): (172, 20000)
# Resulting GPe_spikes ephys data shape is (NxT): (120, 20000)

# %%
from scipy import stats
from tools import params
from tools.dsp.utils import moving_window_mean
from tools.viz.utilityTools import shaded_errorbar

window = 5  # in seconds

fig, ax = plt.subplots(2, 1, figsize=(20, 5), sharex='all', gridspec_kw={'height_ratios': [3, 1]})
areas=["MOp", "SSp", "CP", "VAL"]


for area in areas:
    all_rates = np.concatenate(df_[f"{area}_rates"].values, axis=0)
    means, time_bins = moving_window_mean(all_rates, int(window / Params.BIN_SIZE))
    shaded_errorbar(ax[0], x=time_bins * Params.BIN_SIZE, y=means, errorStat=stats.sem, 
                    color=getattr(params.colors, f"{area}_light", "k"),
                    label=area
                    )
    
all_motion_sensor_x = np.concatenate(df_[f"values_MotSen1_X"].values, axis=0)
all_motion_sensor_y = np.concatenate(df_[f"values_MotSen1_Y"].values, axis=0)

motion_sensor_means_x, _ = moving_window_mean(all_motion_sensor_x, int(window / Params.BIN_SIZE))
motion_sensor_means_y, _ = moving_window_mean(all_motion_sensor_y, int(window / Params.BIN_SIZE))

ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_x, label='x')
ax[1].plot(time_bins * Params.BIN_SIZE, motion_sensor_means_y, label='y')
ax[1].set_ylabel(f'Motion Sensors')
ax[1].legend()


ax[0].set_ylabel(f'Means rate in {window} seconds')
ax[1].set_xlabel(f' Time (s)')
ax[0].axvline(x=480, color="k", linestyle="--")
ax[0].axvline(x=3660, color="k", linestyle="--")
ax[0].set_title(f'Firing rates over time. Session: {session}')
ax[0].legend()
